
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_e3e49_row2_col5,#T_e3e49_row10_col0,#T_e3e49_row12_col2,#T_e3e49_row13_col3{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_e3e49_row2_col9{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_e3e49_row2_col10,#T_e3e49_row9_col11{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_e3e49_row2_col11{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_e3e49_row2_col12,#T_e3e49_row9_col13{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_e3e49_row2_col13,#T_e3e49_row3_col5{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_e3e49_row2_col14{
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }#T_e3e49_row3_col0{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_e3e49_row3_col1,#T_e3e49_row6_col1,#T_e3e49_row9_col2{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_e3e49_row3_col2,#T_e3e49_row6_col7{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_e3e49_row3_col4{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_e3e49_row3_col6,#T_e3e49_row11_col14{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_e3e49_row3_col8,#T_e3e49_row4_col8,#T_e3e49_row5_col2{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_e3e49_row3_col9{
#             background-color:  #dadce0;
#             color:  #000000;
#         }#T_e3e49_row3_col10{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_e3e49_row3_col11,#T_e3e49_row8_col0{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_e3e49_row3_col12{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_e3e49_row3_col14,#T_e3e49_row6_col0,#T_e3e49_row8_col10{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_e3e49_row4_col0{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_e3e49_row4_col1,#T_e3e49_row12_col14,#T_e3e49_row13_col5{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_e3e49_row4_col2,#T_e3e49_row6_col11{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_e3e49_row4_col5,#T_e3e49_row14_col9{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_e3e49_row4_col7,#T_e3e49_row5_col7{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_e3e49_row4_col9,#T_e3e49_row6_col14{
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }#T_e3e49_row4_col11,#T_e3e49_row12_col0,#T_e3e49_row13_col10{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_e3e49_row4_col12,#T_e3e49_row5_col10,#T_e3e49_row6_col9,#T_e3e49_row8_col1{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_e3e49_row4_col13{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_e3e49_row4_col14{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_e3e49_row5_col1,#T_e3e49_row6_col8{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_e3e49_row5_col3,#T_e3e49_row5_col14,#T_e3e49_row13_col0{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_e3e49_row5_col4,#T_e3e49_row10_col12{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_e3e49_row5_col6,#T_e3e49_row8_col13{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_e3e49_row5_col8{
#             backgroun

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#             thall          O2      output
# count  303.000000  303.000000  303.000000
# mean     2.313531   97.484488    0.544554
# std      0.612277    0.352649    0.498835
# min      0.000000   96.500000    0.000000
# 25%      2.000000   97.500000    0.000000
# 50%      2.000000   97.500000    1.000000
# 75%      3.000000   97.500000    1.000000
# max      3.000000   98.600000    1.000000

# %% [markdown]
# ## Model using LinearSVC
#
# 95% accuracy, seed 5

# %%
X = df[['age','sex','cp','trtbps','chol','fbs','restecg','thalachh','exng',
           'oldpeak','slp','caa','thall','O2']]
y = df['output']

# %%
X = X.values
min_max_scaler = preprocessing.StandardScaler()
x_scaled = min_max_scaler.fit_transform(X)
X = pd.DataFrame(x_scaled)

# %%
model = LinearSVC()

SEED = 5
np.random.seed(SEED)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33) # Separa os valores

model.fit(X_train, y_train)

prediction = model.predict(X_test)

accuracy = accuracy_score(prediction, y_test)

accuracy
# Out:
# 0.95

# %%
aux = 0 
for i in range(0, 5000):
    SEED = i
    np.random.seed(SEED)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    
    accuracy = accuracy_score(prediction, y_test)
    
    if accuracy > aux:
        aux = accuracy
        best_seed = i
        print(best_seed, accuracy)

clear_output()
print(best_seed, accuracy)
# Out:
# 5 0.87

# %% [markdown]
# ## Linear with selected correlations
#
# 88% accuracy, best seed 1486

# %%
df_corr = df.corr()

# %%
df_corr = df_corr[df_corr.output > -0.2]
df_corr
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trtbps    0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalachh -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# slp      -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# O2       -0.002252 -0.104556  0.145067  0.043490 -0.022873 -0.015869
# output   -0.225439 -0.280937  0.433798 -0.144931 -0.085239 -0.028046
#
#            restecg  thalachh      exng   oldpeak       slp       caa  \
# cp        0.044421  0.295762 -0.394280 -0.149230  0.119717 -0.181053
# trtbps   -0.114103 -0.046698  0.067616  0.193216 -0.121475  0.101389
# chol     -0.151040 -0.009940  0.067023  0.053952 -0.004038  0.070511
# fbs      -0.084189 -0.008567  0.025665  0.005747 -0.059894  0.137979
# restecg   1.000000  0.044123 -0.070733 -0.058770  0.093045 -0.072042
# thalachh  0.044123  1.000000 -0.378812 -0.344187  0.386784 -0.213177
# slp       0.093045  0.386784 -0.257748 -0.577537  1.000000 -0.080155
# O2        0.097883  0.157801 -0.059248  0.030053 -0.053683 -0.122783
# output    0.137230  0.421741 -0.436757 -0.430696  0.345877 -0.391724
#
#              thall        O2    output
# cp       -0.161736  0.145067  0.433798
# trtbps    0.062210  0.043490 -0.144931
# chol      0.098803 -0.022873 -0.085239
# fbs      -0.032019 -0.015869 -0.028046
# restecg  -0.011981  0.097883  0.137230
# thalachh -0.096439  0.157801  0.421741
# slp      -0.104764 -0.053683  0.345877
# O2        0.002662  1.000000  0.313584
# output   -0.344029  0.313584  1.000000

# %%
columns = df_corr.index
columns = columns.drop('output')

# %%
df_corr = df[columns]
df_corr.head()
# Out:
#    cp  trtbps  chol  fbs  restecg  thalachh  slp    O2
# 0   3     145   233    1        0       150    0  98.6
# 1   2     130   250    0        1       187    0  98.6
# 2   1     130   204    0        0       172    2  98.6
# 3   1     120   236    0        1       178    2  98.6
# 4   0     120   354    0        1       163    2  98.1

# %%
X_corr = df_corr
y_corr = df['output']
X_corr.head()
# Out:
#    cp  trtbps  chol  fbs  restecg  thalachh  slp    O2
# 0   3     145   233    1        0       150    0  98.6
# 1   2     130   250    0        1       187    0  98.6
# 2   1     130   204    0        0       172    2  98.6
# 3   1     120   236    0        1       178    2  98.6
# 4   0     120   354    0        1       163    2  98.1

# %%
X_corr = X_corr.values
min_max_scaler = preprocessing.StandardScaler()
x_corr_scaled = min_max_scaler.fit_transform(X_corr)
X_corr = pd.DataFrame(x_corr_scaled)
X_corr.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.973123  0.763956 -0.256334  2.394438 -1.005832  0.015443 -2.274579
# 1  1.002577 -0.092738  0.072199 -0.417635  0.898962  1.633471 -2.274579
# 2  0.032031 -0.092738 -0.816773 -0.417635 -1.005832  0.977514  0.976352
# 3  0.032031 -0.663867 -0.198357 -0.417635  0.898962  1.239897  0.976352
# 4 -0.938515 -0.663867  2.082050 -0.417635  0.898962  0.583939  0.976352
#
#           7
# 0  3.168468
# 1  3.168468
# 2  3.168468
# 3  3.168468
# 4  1.748282

# %%
model = LinearSVC()

SEED = 2
np.random.rand(SEED)

X_train, X_test, y_train, y_test = train_test_split(X_corr, y_corr, test_size=0.33) # Separa os valores

model.fit(X_train, y_train)

prediction = model.predict(X_test)

accuracy = accuracy_score(prediction, y_test)

accuracy
# Out:
# 0.78

# %%
aux = 0 
for i in range(0, 5000):
    SEED = i
    np.random.seed(SEED)
    
    X_train, X_test, y_train, y_test = train_test_split(X_corr, y_corr, test_size=0.33)
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    
    accuracy = accuracy_score(prediction, y_test)
    
    if accuracy > aux:
        aux = accuracy
        best_seed_corr = i
        print(aux, best_seed_corr)

clear_output()
print(aux, best_seed_corr)
# Out:
# 0.88 1486
