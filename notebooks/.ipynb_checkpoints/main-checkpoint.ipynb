
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_9dfa3_row2_col5,#T_9dfa3_row10_col0,#T_9dfa3_row12_col2,#T_9dfa3_row13_col3{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_9dfa3_row2_col9{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_9dfa3_row2_col10,#T_9dfa3_row9_col11{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_9dfa3_row2_col11{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_9dfa3_row2_col12,#T_9dfa3_row9_col13{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_9dfa3_row2_col13,#T_9dfa3_row3_col5{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_9dfa3_row2_col14{
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }#T_9dfa3_row3_col0{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_9dfa3_row3_col1,#T_9dfa3_row6_col1,#T_9dfa3_row9_col2{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_9dfa3_row3_col2,#T_9dfa3_row6_col7{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_9dfa3_row3_col4{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_9dfa3_row3_col6,#T_9dfa3_row11_col14{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_9dfa3_row3_col8,#T_9dfa3_row4_col8,#T_9dfa3_row5_col2{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_9dfa3_row3_col9{
#             background-color:  #dadce0;
#             color:  #000000;
#         }#T_9dfa3_row3_col10{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_9dfa3_row3_col11,#T_9dfa3_row8_col0{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_9dfa3_row3_col12{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_9dfa3_row3_col14,#T_9dfa3_row6_col0,#T_9dfa3_row8_col10{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_9dfa3_row4_col0{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_9dfa3_row4_col1,#T_9dfa3_row12_col14,#T_9dfa3_row13_col5{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_9dfa3_row4_col2,#T_9dfa3_row6_col11{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_9dfa3_row4_col5,#T_9dfa3_row14_col9{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_9dfa3_row4_col7,#T_9dfa3_row5_col7{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_9dfa3_row4_col9,#T_9dfa3_row6_col14{
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }#T_9dfa3_row4_col11,#T_9dfa3_row12_col0,#T_9dfa3_row13_col10{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_9dfa3_row4_col12,#T_9dfa3_row5_col10,#T_9dfa3_row6_col9,#T_9dfa3_row8_col1{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_9dfa3_row4_col13{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_9dfa3_row4_col14{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_9dfa3_row5_col1,#T_9dfa3_row6_col8{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_9dfa3_row5_col3,#T_9dfa3_row5_col14,#T_9dfa3_row13_col0{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_9dfa3_row5_col4,#T_9dfa3_row10_col12{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_9dfa3_row5_col6,#T_9dfa3_row8_col13{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_9dfa3_row5_col8{
#             backgroun

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#             thall          O2      output
# count  303.000000  303.000000  303.000000
# mean     2.313531   97.484488    0.544554
# std      0.612277    0.352649    0.498835
# min      0.000000   96.500000    0.000000
# 25%      2.000000   97.500000    0.000000
# 50%      2.000000   97.500000    1.000000
# 75%      3.000000   97.500000    1.000000
# max      3.000000   98.600000    1.000000

# %%
def creating_plots(x_plot, y_plot, dataframe):
    fig, ax = plt.subplots(x_plot, y_plot, figsize=(16, 15))
    cont = 0
    
    for i in range(0, x_plot):
        for j in range(0, y_plot):
            if(cont >= len(dataframe.columns)):
                break
            else:
                sns.boxplot(ax=ax[i, j], data=dataframe, x=dataframe[dataframe.columns[cont]],
                           linewidth=2, width=0.3)
                ax[i, j].set_title(dataframe.columns[cont])
                cont+=1   
                
creating_plots(4, 4, df)

# %% [markdown]
# ## Model using LinearSVC
#
# 95% accuracy, seed 5

# %%
X = df[['age','sex','cp','trtbps','chol','fbs','restecg','thalachh','exng',
           'oldpeak','slp','caa','thall','O2']]
y = df['output']

# %%
X = X.values
min_max_scaler = preprocessing.StandardScaler()
x_scaled = min_max_scaler.fit_transform(X)
X = pd.DataFrame(x_scaled)

# %%
model = LinearSVC()

SEED = 5
np.random.seed(SEED)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33) # Separa os valores

model.fit(X_train, y_train)

prediction = model.predict(X_test)

accuracy = accuracy_score(prediction, y_test)

accuracy
# Out:
# 0.95

# %%
aux = 0 
for i in range(0, 5000):
    SEED = i
    np.random.seed(SEED)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    
    accuracy = accuracy_score(prediction, y_test)
    
    if accuracy > aux:
        aux = accuracy
        best_seed = i
        print(best_seed, accuracy)

clear_output()
print(best_seed, aux)
# Out:
# 5 0.95

# %% [markdown]
# ## Linear with selected correlations
#
# 88% accuracy, best seed 1486

# %%
df_corr = df.corr()

# %%
df_corr = df_corr[df_corr.output > -0.2]
df_corr
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trtbps    0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalachh -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# slp      -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# O2       -0.002252 -0.104556  0.145067  0.043490 -0.022873 -0.015869
# output   -0.225439 -0.280937  0.433798 -0.144931 -0.085239 -0.028046
#
#            restecg  thalachh      exng   oldpeak       slp       caa  \
# cp        0.044421  0.295762 -0.394280 -0.149230  0.119717 -0.181053
# trtbps   -0.114103 -0.046698  0.067616  0.193216 -0.121475  0.101389
# chol     -0.151040 -0.009940  0.067023  0.053952 -0.004038  0.070511
# fbs      -0.084189 -0.008567  0.025665  0.005747 -0.059894  0.137979
# restecg   1.000000  0.044123 -0.070733 -0.058770  0.093045 -0.072042
# thalachh  0.044123  1.000000 -0.378812 -0.344187  0.386784 -0.213177
# slp       0.093045  0.386784 -0.257748 -0.577537  1.000000 -0.080155
# O2        0.097883  0.157801 -0.059248  0.030053 -0.053683 -0.122783
# output    0.137230  0.421741 -0.436757 -0.430696  0.345877 -0.391724
#
#              thall        O2    output
# cp       -0.161736  0.145067  0.433798
# trtbps    0.062210  0.043490 -0.144931
# chol      0.098803 -0.022873 -0.085239
# fbs      -0.032019 -0.015869 -0.028046
# restecg  -0.011981  0.097883  0.137230
# thalachh -0.096439  0.157801  0.421741
# slp      -0.104764 -0.053683  0.345877
# O2        0.002662  1.000000  0.313584
# output   -0.344029  0.313584  1.000000

# %%
columns = df_corr.index
columns = columns.drop('output')

# %%
df_corr = df[columns]
df_corr.head()
# Out:
#    cp  trtbps  chol  fbs  restecg  thalachh  slp    O2
# 0   3     145   233    1        0       150    0  98.6
# 1   2     130   250    0        1       187    0  98.6
# 2   1     130   204    0        0       172    2  98.6
# 3   1     120   236    0        1       178    2  98.6
# 4   0     120   354    0        1       163    2  98.1

# %%
X_corr = df_corr
y_corr = df['output']
X_corr.head()
# Out:
#    cp  trtbps  chol  fbs  restecg  thalachh  slp    O2
# 0   3     145   233    1        0       150    0  98.6
# 1   2     130   250    0        1       187    0  98.6
# 2   1     130   204    0        0       172    2  98.6
# 3   1     120   236    0        1       178    2  98.6
# 4   0     120   354    0        1       163    2  98.1

# %%
X_corr = X_corr.values
min_max_scaler = preprocessing.StandardScaler()
x_corr_scaled = min_max_scaler.fit_transform(X_corr)
X_corr = pd.DataFrame(x_corr_scaled)
X_corr.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.973123  0.763956 -0.256334  2.394438 -1.005832  0.015443 -2.274579
# 1  1.002577 -0.092738  0.072199 -0.417635  0.898962  1.633471 -2.274579
# 2  0.032031 -0.092738 -0.816773 -0.417635 -1.005832  0.977514  0.976352
# 3  0.032031 -0.663867 -0.198357 -0.417635  0.898962  1.239897  0.976352
# 4 -0.938515 -0.663867  2.082050 -0.417635  0.898962  0.583939  0.976352
#
#           7
# 0  3.168468
# 1  3.168468
# 2  3.168468
# 3  3.168468
# 4  1.748282

# %%
model = LinearSVC()

SEED = 2
np.random.rand(SEED)

X_train, X_test, y_train, y_test = train_test_split(X_corr, y_corr, test_size=0.33) # Separa os valores

model.fit(X_train, y_train)

prediction = model.predict(X_test)

accuracy = accuracy_score(prediction, y_test)

accuracy
# Out:
# 0.78

# %%
aux = 0 
for i in range(0, 5000):
    SEED = i
    np.random.seed(SEED)
    
    X_train, X_test, y_train, y_test = train_test_split(X_corr, y_corr, test_size=0.33)
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    
    accuracy = accuracy_score(prediction, y_test)
    
    if accuracy > aux:
        aux = accuracy
        best_seed_corr = i
        print(aux, best_seed_corr)

clear_output()
print(aux, best_seed_corr)
# Out:
# 0.88 1486

# %% [markdown]
# ## Using neural network

# %%
X = df[['age','sex','cp','trtbps','chol','fbs','restecg','thalachh','exng',
           'oldpeak','slp','caa','thall','O2']]
y = df['output']

# %%
X = X.values
min_max_scaler = preprocessing.StandardScaler()
x_scaled = min_max_scaler.fit_transform(X)
X = pd.DataFrame(x_scaled)
X = np.array(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("GPUs Available: ", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# GPUs Available:  1

# %%
model = Sequential([
    Dense(units=16, input_shape=(14,), activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=2, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                240
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                544
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 850
# Trainable params: 850
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x=X_train, y=y_train, batch_size=10, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 21/21 - 1s - loss: 0.7026 - accuracy: 0.5517
# Epoch 2/100
# 21/21 - 0s - loss: 0.6851 - accuracy: 0.5862
# Epoch 3/100
# 21/21 - 0s - loss: 0.6693 - accuracy: 0.6010
# Epoch 4/100
# 21/21 - 0s - loss: 0.6537 - accuracy: 0.6158
# Epoch 5/100
# 21/21 - 0s - loss: 0.6401 - accuracy: 0.6404
# Epoch 6/100
# 21/21 - 0s - loss: 0.6263 - accuracy: 0.6749
# Epoch 7/100
# 21/21 - 0s - loss: 0.6139 - accuracy: 0.6946
# Epoch 8/100
# 21/21 - 0s - loss: 0.6017 - accuracy: 0.7143
# Epoch 9/100
# 21/21 - 0s - loss: 0.5897 - accuracy: 0.7291
# Epoch 10/100
# 21/21 - 0s - loss: 0.5789 - accuracy: 0.7488
# Epoch 11/100
# 21/21 - 0s - loss: 0.5675 - accuracy: 0.7635
# Epoch 12/100
# 21/21 - 0s - loss: 0.5570 - accuracy: 0.7882
# Epoch 13/100
# 21/21 - 0s - loss: 0.5468 - accuracy: 0.8030
# Epoch 14/100
# 21/21 - 0s - loss: 0.5370 - accuracy: 0.8079
# Epoch 15/100
# 21/21 - 0s - loss: 0.5272 - accuracy: 0.8177
# Epoch 16/100
# 21/21 - 0s - loss: 0.5181 - accuracy: 0.8177
# Epoch 17/100
# 21/21 - 0s - loss: 0.5097 - accuracy: 0.8227
# Epoch 18/100
# 21/21 - 0s - loss: 0.5012 - accuracy: 0.8325
# Epoch 19/100
# 21/21 - 0s - loss: 0.4927 - accuracy: 0.8325
# Epoch 20/100
# 21/21 - 0s - loss: 0.4848 - accuracy: 0.8374
# Epoch 21/100
# 21/21 - 0s - loss: 0.4769 - accuracy: 0.8374
# Epoch 22/100
# 21/21 - 0s - loss: 0.4693 - accuracy: 0.8473
# Epoch 23/100
# 21/21 - 0s - loss: 0.4619 - accuracy: 0.8473
# Epoch 24/100
# 21/21 - 0s - loss: 0.4547 - accuracy: 0.8522
# Epoch 25/100
# 21/21 - 0s - loss: 0.4478 - accuracy: 0.8571
# Epoch 26/100
# 21/21 - 0s - loss: 0.4413 - accuracy: 0.8571
# Epoch 27/100
# 21/21 - 0s - loss: 0.4347 - accuracy: 0.8621
# Epoch 28/100
# 21/21 - 0s - loss: 0.4284 - accuracy: 0.8621
# Epoch 29/100
# 21/21 - 0s - loss: 0.4223 - accuracy: 0.8571
# Epoch 68/100
# 21/21 - 0s - loss: 0.2798 - accuracy: 0.8818
# Epoch 69/100
# 21/21 - 0s - loss: 0.2777 - accuracy: 0.8867
# Epoch 70/100
# 21/21 - 0s - loss: 0.2755 - accuracy: 0.8867
# Epoch 71/100
# 21/21 - 0s - loss: 0.2733 - accuracy: 0.8867
# Epoch 72/100
# 21/21 - 0s - loss: 0.2713 - accuracy: 0.8867
# Epoch 73/100
# 21/21 - 0s - loss: 0.2693 - accuracy: 0.8867
# Epoch 74/100
# 21/21 - 0s - loss: 0.2674 - accuracy: 0.8867
# Epoch 75/100
# 21/21 - 0s - loss: 0.2652 - accuracy: 0.8966
# Epoch 76/100
# 21/21 - 0s - loss: 0.2634 - accuracy: 0.8966
# Epoch 77/100
# 21/21 - 0s - loss: 0.2613 - accuracy: 0.8966
# Epoch 78/100
# 21/21 - 0s - loss: 0.2595 - accuracy: 0.8966
# Epoch 79/100
# 21/21 - 0s - loss: 0.2577 - accuracy: 0.9015
# Epoch 80/100
# 21/21 - 0s - loss: 0.2558 - accuracy: 0.9015
# Epoch 81/100
# 21/21 - 0s - loss: 0.2540 - accuracy: 0.9064
# Epoch 82/100
# 21/21 - 0s - loss: 0.2522 - accuracy: 0.9064
# Epoch 83/100
# 21/21 - 0s - loss: 0.2504 - accuracy: 0.9064
# Epoch 84/100
# 21/21 - 0s - loss: 0.2486 - accuracy: 0.9064
# Epoch 85/100
# 21/21 - 0s - loss: 0.2469 - accuracy: 0.9064
# Epoch 86/100
# 21/21 - 0s - loss: 0.2454 - accuracy: 0.9064
# Epoch 87/100
# 21/21 - 0s - loss: 0.2439 - accuracy: 0.9064
# Epoch 88/100
# 21/21 - 0s - loss: 0.2422 - accuracy: 0.9064
# Epoch 89/100
# 21/21 - 0s - loss: 0.2406 - accuracy: 0.9064
# Epoch 90/100
# 21/21 - 0s - loss: 0.2390 - accuracy: 0.9113
# Epoch 91/100
# 21/21 - 0s - loss: 0.2375 - accuracy: 0.9113
# Epoch 92/100
# 21/21 - 0s - loss: 0.2361 - accuracy: 0.9113
# Epoch 93/100
# 21/21 - 0s - loss: 0.2345 - accuracy: 0.9163
# Epoch 94/100
# 21/21 - 0s - loss: 0.2329 - accuracy: 0.9113
# Epoch 95/100
# 21/21 - 0s - loss: 0.2316 - accuracy: 0.9163
# Epoch 96/100
# 21/21 - 0s - loss: 0.2300 - accuracy: 0.9163
# Epoch 97/100
# 21/21 - 0s - loss: 0.2286 - accuracy: 0.9163
# Epoch 98/100
# 21/21 - 0s - loss: 0.2272 - accuracy: 0.9163
# Epoch 99/100
# 21/21 - 0s - loss: 0.2257 - accuracy: 0.9163
# Epoch 100/100
# 21/21 - 0s - loss: 0.2245 - accuracy: 0.9163

# %%
y_test
# Out:
# 44     1
# 236    0
# 140    1
# 302    0
# 8      1
#       ..
# 102    1
# 97     1
# 177    0
# 206    0
# 51     1
# Name: output, Length: 100, dtype: int64

# %%
prediction = model.predict(X_test, batch_size=10, verbose=0)

# %%
for i in prediction:
    print(i)
# Out:
# [0.05993977 0.94006026]
# [0.6562339 0.3437661]
# [0.03308673 0.9669133 ]
# [0.05295123 0.94704884]
# [0.09718296 0.9028171 ]
# [0.9960051  0.00399485]
# [0.3516874 0.6483126]
# [0.9702537  0.02974624]
# [0.03256206 0.9674379 ]
# [0.03352451 0.9664755 ]
# [0.00512256 0.9948775 ]
# [0.03001181 0.96998817]
# [0.03828342 0.96171653]
# [0.99890697 0.00109305]
# [0.01246371 0.98753625]
# [0.748381 0.251619]
# [0.15634999 0.84365004]
# [0.14910023 0.85089976]
# [0.93349516 0.06650487]
# [0.01254967 0.98745036]
# [0.57438934 0.42561063]
# [0.02202363 0.9779764 ]
# [0.03710679 0.9628932 ]
# [0.6998401  0.30015984]
# [0.0827342 0.9172657]
# [0.6236136  0.37638637]
# [0.10149601 0.898504  ]
# [0.9729772 0.0270228]
# [0.96357685 0.03642312]
# [0.7113673 0.2886327]
# [0.0718051  0.92819494]
# [0.99766684 0.00233323]
# [0.05892712 0.9410729 ]
# [0.01757094 0.982429  ]
# [0.11716323 0.88283676]
# [0.9696656  0.03033438]
# [0.98198235 0.01801758]
# [0.9985025  0.00149748]
# [0.9972844  0.00271564]
# [0.1531057  0.84689426]
# [0.01343572 0.9865643 ]
# [0.34859005 0.6514099 ]
# [0.43193743 0.5680626 ]
# [0.00729748 0.9927025 ]
# [0.40974244 0.5902575 ]
# [0.00412142 0.9958786 ]
# [0.922906   0.07709403]
# [0.99645007 0.00354995]
# [0.13984281 0.8601572 ]
# [0.05751139 0.9424887 ]
# [0.01039015 0.98960984]
# [0.58079493 0.41920504]
# [0.75100005 0.24899997]
# [0.90608525 0.09391472]
# [0.00889924 0.9911007 ]
# [0.09391833 0.9060816 ]
# [0.33221692 0.66778314]
# [0.1642312 0.8357688]
# [0.9875974  0.01240261]
# [0.9976829  0.00231701]
# [0.24542002 0.75457996]
# [0.02613913 0.9738609 ]
# [0.911544 0.088456]
# [0.09832364 0.90167636]
# [0.13826232 0.86173767]
# [0.061324   0.93867606]
# [0.5148443  0.48515576]
# [0.97874326 0.02125673]
# [0.98479545 0.01520456]
# [0.01997395 0.980026  ]
# [0.06522132 0.93477863]
# [0.9564506  0.04354947]
# [0.21381757 0.7861824 ]
# [0.01475264 0.9852474 ]
# [0.35958827 0.6404117 ]
# [0.00380951 0.9961904 ]
# [0.9125321  0.08746796]
# [0.06723033 0.9327696 ]
# [0.15304871 0.8469513 ]
# [0.9979201  0.00207998]
# [0.9926426  0.00735746]
# [0.02206396 0.977936  ]
# [0.02126913 0.97873086]
# [0.04448151 0.95551854]
# [0.4631865 0.5368135]
# [0.9970432  0.00295682]
# [0.03815123 0.96184874]
# [0.95560104 0.044399  ]
# [0.56349987 0.4365002 ]
# [0.00551218 0.9944878 ]
# [0.27206686 0.7279331 ]
# [0.9909922  0.00900785]
# [0.02431517 0.97568476]
# [0.08386104 0.91613895]
# [0.27206686 0.7279331 ]
# [0.05740417 0.94259584]
# [0.93651336 0.0634866 ]
# [0.08130565 0.9186943 ]
# [0.9623996  0.03760038]
# [0.46764553 0.5323544 ]

# %%
rounded_prediction = np.argmax(prediction, axis=-1)

# %%
accuracy = accuracy_score(y_test, rounded_prediction)
accuracy
# Out:
# 0.84
